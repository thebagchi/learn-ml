# %%
import sys

print(sys.getsizeof(1))          
print(sys.getsizeof("hello"))    
print(sys.getsizeof([]))         
print(sys.getsizeof([1, 2, 3]))
# Out:
# 28
# 54
# 56
# 88

# %%
import numpy as np

arr = np.array([1,2,3])
print(sys.getsizeof(arr))
# Out:
# 136
