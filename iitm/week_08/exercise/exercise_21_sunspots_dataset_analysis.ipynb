# %%
import statsmodels.api as sm
import pandas as pd

df = sm.datasets.sunspots.load_pandas().data
print(df.shape)
df.head()
# Out:
# (309, 2)
#      YEAR  SUNACTIVITY
# 0  1700.0          5.0
# 1  1701.0         11.0
# 2  1702.0         16.0
# 3  1703.0         23.0
# 4  1704.0         36.0
