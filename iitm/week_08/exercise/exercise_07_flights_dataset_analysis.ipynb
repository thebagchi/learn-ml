# %%
import seaborn as sns

df = sns.load_dataset('flights')
print(df.shape)
df.head()
# Out:
# (144, 3)
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
