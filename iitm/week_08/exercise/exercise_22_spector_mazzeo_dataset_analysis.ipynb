# %%
import statsmodels.api as sm
import pandas as pd

df = sm.datasets.spector.load_pandas().data
print(df.shape)
df.head()
# Out:
# (32, 4)
#     GPA  TUCE  PSI  GRADE
# 0  2.66  20.0  0.0    0.0
# 1  2.89  22.0  0.0    0.0
# 2  3.28  24.0  0.0    0.0
# 3  2.92  12.0  0.0    0.0
# 4  4.00  21.0  0.0    1.0
