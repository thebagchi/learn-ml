# %% [markdown]
# # Deep Q-Network (DQN) — Reinforcement Learning
# **Environment:** CartPole-v1
# **Metrics:** Cumulative Reward, Avg Reward per Episode

# %%
from utils.rl import DQNAgent

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import random
import gymnasium as gym

# %%
env = gym.make("CartPole-v1")
state_dim  = env.observation_space.shape[0]
action_dim = env.action_space.n
print(f"State dim: {state_dim}, Actions: {action_dim}")
# Out:
# State dim: 4, Actions: 2

# %%
agent  = DQNAgent().train(env, episodes=300)
report = agent.evaluate(env, episodes=100)
for k, v in report.items():
    print(f"{k}: {v:.2f}")
# Out:
# /home/sandeep/workspace/learn-ml/ml-301/usage/utils/rl.py:239: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   states_t  = torch.tensor(states,  dtype=torch.float32)
# Episode 50  avg_reward=18.2  eps=0.778
# Episode 100  avg_reward=16.6  eps=0.606
# Episode 150  avg_reward=15.6  eps=0.471
# Episode 200  avg_reward=22.4  eps=0.367
# Episode 250  avg_reward=31.5  eps=0.286
# Episode 300  avg_reward=48.7  eps=0.222
# avg_reward: 54.61
# cumulative_reward: 5461.00
# avg_steps: 54.61
