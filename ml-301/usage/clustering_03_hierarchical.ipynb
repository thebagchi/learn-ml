# %% [markdown]
# # Hierarchical (Agglomerative) Clustering
# **Metrics:** Silhouette Score, Davies-Bouldin Index

# %%
from utils.clustering import Hierarchical

from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score
import numpy as np
import pandas as pd

# %%
X, _ = make_blobs(n_samples=500, centers=4, cluster_std=0.8, random_state=42)
scaler = StandardScaler()
X = scaler.fit_transform(X)

display(pd.DataFrame(X, columns=[f"feat_{i}" for i in range(X.shape[1])]).head())
# Out:
#      feat_0    feat_1
# 0 -0.864253  0.616469
# 1 -1.077736 -1.560034
# 2  1.867820 -0.247872
# 3  0.108640  0.788637
# 4 -0.482380 -1.605048

# %%
model  = Hierarchical(n_clusters=4, linkage="ward").train(X)
labels = model.predict(X)
report = model.evaluate(X)
for k, v in report.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")
# Out:
# silhouette: 0.8393
# davies_bouldin: 0.2247
# n_clusters: 4
