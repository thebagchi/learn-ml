# %% [markdown]
# # Policy Gradient (REINFORCE) — Reinforcement Learning
# **Environment:** CartPole-v1
# **Metrics:** Cumulative Reward, Avg Reward per Episode

# %%
from utils.rl import PolicyGradientAgent

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import gymnasium as gym

# %%
env = gym.make("CartPole-v1")
state_dim  = env.observation_space.shape[0]
action_dim = env.action_space.n
print(f"State dim: {state_dim}, Actions: {action_dim}")
# Out:
# State dim: 4, Actions: 2

# %%
agent  = PolicyGradientAgent().train(env, episodes=500)
report = agent.evaluate(env, episodes=100)
for k, v in report.items():
    print(f"{k}: {v:.2f}")
# Out:
# Episode 100  avg_reward=28.9
# Episode 200  avg_reward=52.8
# Episode 300  avg_reward=95.5
# Episode 400  avg_reward=222.1
# Episode 500  avg_reward=260.5
# avg_reward: 496.81
# cumulative_reward: 49681.00
